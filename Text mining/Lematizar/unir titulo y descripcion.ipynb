# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import re
import shutil
import string
import tensorflow as tf
from tensorflow.keras import regularizers

from tensorflow.keras import layers
from tensorflow.keras import losses

from collections import Counter


import pandas as pd
import numpy as np

import sklearn


from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from tensorflow.keras import preprocessing
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


import seaborn as sns

import pydot

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
rtitle = "/content/drive/MyDrive/TFM Big Data & BA/Propuestas/Proyecto Final/2 - Text Mining/titulos.csv"
rdata = "/content/drive/MyDrive/TFM Big Data & BA/Propuestas/Proyecto Final/0 - Dataset/train_data.csv"
rdescr = "/content/drive/MyDrive/TFM Big Data & BA/Propuestas/Proyecto Final/0 - Dataset/descr.csv"
rdescr_0 = "/content/drive/MyDrive/TFM Big Data & BA/Propuestas/Proyecto Final/2 - Text Mining/descr_0.csv"

# %%
dfdata = pd.read_csv(rdata)
dftitle = pd.read_csv(rtitle)
dfdesc = pd.read_csv(rdescr)
dfdesc_0 = pd.read_csv(rdescr_0)

# %%
dfdesc
# Out:
#         Unnamed: 0  ...                                          normaliza
# 0                0  ...  продать гарнитура динамика китай оригинал подк...
# 1                1  ...  зарядный устройство подойти любой современный ...
# 2                2  ...  отличный крепкий чехол защита удар отлично под...
# 3                3  ...  продать дисплей смартфон iphone покупка штука ...
# 4                4  ...  аккумулятор samsung galaxy star plus duos ориг...
# ...            ...  ...                                                ...
# 208001      622753  ...  состояние новый юбилейном стоить 750р продават...
# 208002      622754  ...                                       одной струна
# 208003      622756  ...  продать педаль эффект distortion полный назван...
# 208004      622757  ...  использоваться минимально домашний условие сос...
# 208005      622758  ...                                   хороший сотояние
#
# [208006 rows x 4 columns]

# %%
dfdescr = pd.concat([dfdesc,dfdesc_0])

# %%
dfdescr
# Out:
#         Unnamed: 0  ...                                          normaliza
# 0                0  ...  продать гарнитура динамика китай оригинал подк...
# 1                1  ...  зарядный устройство подойти любой современный ...
# 2                2  ...  отличный крепкий чехол защита удар отлично под...
# 3                3  ...  продать дисплей смартфон iphone покупка штука ...
# 4                4  ...  аккумулятор samsung galaxy star plus duos ориг...
# ...            ...  ...                                                ...
# 414751      622752  ...  кейс новенький малюсенький волосяной бесплатны...
# 414752      622755  ...                  струна цветной гитары новый метал
# 414753      622759  ...  продать ремень гитара разный расцветка отправи...
# 414754      622760  ...  продаваться педаль эффект отличный состояние ц...
# 414755      622761  ...           нейлоновый сумка микшер аксессуар x x mm
#
# [622762 rows x 4 columns]

# %%
dfdata.rename({'Unnamed: 0':'llave'}, axis=1, inplace=True)
dftitle.rename({'Unnamed: 0':'llave','normaliza':'Titulo'}, axis=1, inplace=True)
dfdescr.rename({'Unnamed: 0':'llave','normaliza':'Descripcion'}, axis=1, inplace=True)

# %%
dftitle = dftitle.drop(['ti', 'ti_processed'], axis=1)
dfdescr = dfdescr.drop(['de', 'de_processed'], axis=1)

# %%
df_final = dfdata.merge(dftitle, on='llave')

# %%
df_textm = df_final.merge(dfdescr, on='llave')

# %%
df_textm
# Out:
#          llave  ...                                        Descripcion
# 0            0  ...  продать гарнитура динамика китай оригинал подк...
# 1            1  ...  зарядный устройство подойти любой современный ...
# 2            2  ...  отличный крепкий чехол защита удар отлично под...
# 3            3  ...  продать дисплей смартфон iphone покупка штука ...
# 4            4  ...  аккумулятор samsung galaxy star plus duos ориг...
# ...        ...  ...                                                ...
# 622757  622757  ...  использоваться минимально домашний условие сос...
# 622758  622758  ...                                   хороший сотояние
# 622759  622759  ...  продать ремень гитара разный расцветка отправи...
# 622760  622760  ...  продаваться педаль эффект отличный состояние ц...
# 622761  622761  ...           нейлоновый сумка микшер аксессуар x x mm
#
# [622762 rows x 20 columns]

# %%
from google.colab import files
df_textm.to_csv('df_textm.csv')
files.download('df_textm.csv')
